# %%
import streamlit as st
from agentic_data_analysis_agent import run_agent
import pandas as pd

st.set_page_config(page_title="Agentic Data Analysis AI", layout="wide")

st.title("📊 Agentic Data Analysis AI")
st.write("Upload a CSV. The agent decides what to analyze, forms hypotheses, and tests them.")

uploaded_file = st.file_uploader("Upload CSV file", type=["csv"])

if uploaded_file:
    df = pd.read_csv(uploaded_file)
    st.write("Preview of Data:")
    st.dataframe(df.head())

    with open("temp.csv", "wb") as f:
        f.write(uploaded_file.getbuffer())

    if st.button("Run Agent"):
        st.write("Running agent... check console output")
        run_agent("temp.csv")
