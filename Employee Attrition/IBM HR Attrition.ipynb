# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
hr_df = pd.read_csv("C:/Users/SOHAM PAL/Desktop/Python Programs/ML & EDA/Employee Attrition.csv")
hr_df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
hr_df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
hr_df.drop_duplicates(inplace=True)
hr_df.shape
# Out:
# (1470, 35)

# %%
hr_df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
hr_df.skew(numeric_only=True)
# Out:
# Age                         0.413286
# DailyRate                  -0.003519
# DistanceFromHome            0.958118
# Education                  -0.289681
# EmployeeCount               0.000000
# EmployeeNumber              0.016574
# EnvironmentSatisfaction    -0.321654
# HourlyRate                 -0.032311
# JobInvolvement             -0.498419
# JobLevel                    1.025401
# JobSatisfaction            -0.329672
# MonthlyIncome               1.369817
# MonthlyRate                 0.018578
# NumCompaniesWorked          1.026471
# PercentSalaryHike           0.821128
# PerformanceRating           1.921883
# RelationshipSatisfaction   -0.302828
# StandardHours               0.000000
# StockOptionLevel            0.968980
# TotalWorkingYears           1.117172
# TrainingTimesLastYear       0.553124
# WorkLifeBalance            -0.552480
# YearsAtCompany              1.764529
# YearsInCurrentRole          0.917363
# YearsSinceLastPromotion     1.984290
# ...

# %% [markdown]
# ### The dataset contains 1,470 rows and 35 columns. Here's a summary of the dataset structure:
#
# 1. Data Types: The dataset includes both numerical and categorical variables. All fields have complete values (no missing data).
# 2. Columns: Some key columns include Age, Attrition (whether the employee left or stayed), BusinessTravel, Department, JobRole, MonthlyIncome, OverTime, and YearsAtCompany, among others.
# 3. Target Variable: The Attrition column, which is categorical, can be treated as the target variable for predictive modeling.

# %%
hr_df.drop(columns = ['EmployeeCount', 'StandardHours', 'Over18', 'EmployeeNumber'], inplace = True)

# %%
#outlier detection
def outliers_det(df,column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = q3 - q1
    up = q3 + 1.5*iqr
    lb = q1 - 1.5*iqr

    out = df[(df[column] > up) | (df[column] < lb)]
    return out

# %%
selected_columns = hr_df.select_dtypes(include = ["number"])
for col in selected_columns:
    out = outliers_det(hr_df,col)
    if len(out)>0:
        print("Outliers found in",col,"and the count is",len(out))   
    else:
        print("No outliers found in", col)
# Out:
# No outliers found in Age
# No outliers found in DailyRate
# No outliers found in DistanceFromHome
# No outliers found in Education
# No outliers found in EnvironmentSatisfaction
# No outliers found in HourlyRate
# No outliers found in JobInvolvement
# No outliers found in JobLevel
# No outliers found in JobSatisfaction
# Outliers found in MonthlyIncome and the count is 114
# No outliers found in MonthlyRate
# No outliers found in NumCompaniesWorked
# No outliers found in PercentSalaryHike
# Outliers found in PerformanceRating and the count is 226
# No outliers found in RelationshipSatisfaction
# Outliers found in StockOptionLevel and the count is 85
# No outliers found in TotalWorkingYears
# Outliers found in TrainingTimesLastYear and the count is 184
# No outliers found in WorkLifeBalance
# Outliers found in YearsAtCompany and the count is 104
# No outliers found in YearsInCurrentRole
# Outliers found in YearsSinceLastPromotion and the count is 107
# ...

# %%
#outlier treatment
from scipy.stats import mstats
for col in selected_columns:
    hr_df[col] = mstats.winsorize(hr_df[col], limits=[0.05, 0.05])  #capping the 5th and 95th percentile values

# %%
selected_columns = hr_df.select_dtypes(include = ["number"])
for col in selected_columns:
    out = outliers_det(hr_df,col)
    if len(out)>0:
        print("Outliers found in",col,"and the count is",len(out))   
    else:
        print("No outliers found in", col)
# Out:
# No outliers found in Age
# No outliers found in DailyRate
# No outliers found in DistanceFromHome
# No outliers found in Education
# No outliers found in EnvironmentSatisfaction
# No outliers found in HourlyRate
# No outliers found in JobInvolvement
# No outliers found in JobLevel
# No outliers found in JobSatisfaction
# Outliers found in MonthlyIncome and the count is 114
# No outliers found in MonthlyRate
# No outliers found in NumCompaniesWorked
# No outliers found in PercentSalaryHike
# Outliers found in PerformanceRating and the count is 226
# No outliers found in RelationshipSatisfaction
# Outliers found in StockOptionLevel and the count is 85
# No outliers found in TotalWorkingYears
# Outliers found in TrainingTimesLastYear and the count is 184
# No outliers found in WorkLifeBalance
# Outliers found in YearsAtCompany and the count is 104
# No outliers found in YearsInCurrentRole
# Outliers found in YearsSinceLastPromotion and the count is 107
# ...

# %% [markdown]
# ## Analyzing the Attrition distribution and key relationships.

# %%
# Set plot style
sns.set(style="whitegrid")

# Analyze the distribution of Attrition
attrition_counts = hr_df['Attrition'].value_counts()

# Plot the distribution of Attrition
plt.figure(figsize=(6,4))
sns.barplot(x=attrition_counts.index, y=attrition_counts.values, palette='coolwarm')
plt.title('Attrition Distribution')
plt.ylabel('Number of Employees')
plt.xlabel('Attrition Status')
plt.show()

# Further exploration - Relation between Attrition and other key factors
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='Age', data=hr_df, palette='coolwarm')
plt.title('Attrition vs Age')
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='MonthlyIncome', data=hr_df, palette='coolwarm')
plt.title('Attrition vs Monthly Income')
plt.show()

# %% [markdown]
# ###
# Attrition Distribution:
# A significant majority of employees have not left the company, while a smaller proportion have experienced attrition (i.e., left).
#
# Attrition vs Age:
# Employees who left the company tend to have a slightly younger median age compared to those who stayed. There is a visible concentration of younger employees among those who left.
#
# Attrition vs Monthly Income:
# Employees with higher Monthly Incomes seem less likely to leave. Those who left the company generally have lower incomes, which could indicate a correlation between salary and employee retention.

# %% [markdown]
# ## Exploring the relationship between Attrition and other categorical features: JobRole, OverTime, and WorkLifeBalance

# %%
# Plotting Attrition vs JobRole
plt.figure(figsize=(12,6))
sns.countplot(x='JobRole', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Job Role')
plt.xticks(rotation=45)
plt.show()

# Plotting Attrition vs OverTime
plt.figure(figsize=(8,5))
sns.countplot(x='OverTime', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Overtime Status')
plt.show()

# Plotting Attrition vs WorkLifeBalance
plt.figure(figsize=(8,5))
sns.countplot(x='WorkLifeBalance', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Work-Life Balance')
plt.show()

# %% [markdown]
# ###
# Attrition by Job Role:
# Certain roles like Sales Representatives and Laboratory Technicians have higher attrition rates compared to others. Senior roles, such as Research Directors and Managers, exhibit lower attrition, indicating that employees in higher positions may be more stable, so we will perform this comparison again numerically to extract more accurate readings from data.
#
# Attrition by Overtime:
# Employees who work OverTime are more likely to experience attrition. This suggests that increased overtime work might lead to dissatisfaction or burnout, contributing to higher turnover rates.
#
# Attrition by Work-Life Balance:
# Employees who report a lower Work-Life Balance (rated 1 or 2) are more likely to leave the company. Those with better work-life balance (rated 3 or 4) tend to stay, reinforcing the importance of maintaining balance for retention.

# %% [markdown]
# ## Education Distribution

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Education', data=hr_df, palette='coolwarm')
plt.title('Education Distribution')
plt.show()

# %% [markdown]
# ###
# 1. The count of employees with different education levels shows that most employees have mid-level education (Education level 3 and 4).
# 2. This implies the workforce consists mainly of employees with either a Bachelor’s degree or equivalent, reflecting the level of qualification typically required by the company.

# %% [markdown]
# ## Age Distribution

# %%
plt.figure(figsize=(8,5))
sns.histplot(hr_df['Age'], bins=20, kde=True, color='blue')
plt.title('Age Distribution')
plt.show()

# %% [markdown]
# ###
# 1. The age distribution appears relatively balanced but is skewed slightly towards the younger demographic. The majority of employees are between the ages of 25-40.
# 2. This suggests that the company might have a relatively young workforce, which could impact attrition, career progression, and training programs.

# %% [markdown]
# ## Field of Study Distribution

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='EducationField', data=hr_df, palette='coolwarm')
plt.title('Field of Study Distribution')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ###
# The most common fields of study include Life Sciences and Medical. This indicates that the company might operate in industries related to healthcare, pharmaceuticals, or biotechnology.

# %% [markdown]
# ## Gender Distribution

# %%
gender_counts = hr_df['Gender'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', colors=['lightblue', 'lightcoral'], startangle=90)
plt.title('Gender Distribution')
plt.show()

# %% [markdown]
# ###
# The gender distribution appears skewed with more males than females in the workforce. This imbalance could raise questions about diversity and inclusion practices within the company.

# %% [markdown]
# ## Marital Status

# %%
marital_counts = hr_df['MaritalStatus'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(marital_counts, labels=marital_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Marital Distribution')
plt.show()

# %% [markdown]
# ###
# This distribution raises an interesting question about whether marital status has any influence on attrition. While marital status may not serve as a direct predictor of attrition, it could act as an indirect factor.

# %% [markdown]
# ## Workplace Satisfaction & Environment

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='JobSatisfaction', data=hr_df, palette='coolwarm')
plt.title('Job Satisfaction Distribution')
plt.show()

# %% [markdown]
# ### Job Satisfaction Analysis:
# 1. The majority of employees report moderate to high levels of job satisfaction. However, a notable portion has lower satisfaction, which could contribute to higher attrition rates among these employees.
# 2. This suggests room for improving job satisfaction through better engagement and feedback mechanisms.

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='EnvironmentSatisfaction', data=hr_df, palette='coolwarm')
plt.title('Environment Satisfaction Distribution')
plt.show()

# %% [markdown]
# ### Environment Satisfaction Levels:
# A similar trend is observed in environmental satisfaction, where most employees rate their work environment positively. However, improving the satisfaction for those who rate it low could help improve retention.

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Education', y='MonthlyIncome', data=hr_df, palette='coolwarm')
plt.title('Median Monthly Income by Education Level')
plt.show()

# %% [markdown]
# ### Median Monthly Income by Education Level:
# 1. Employees with higher education tend to earn more, which is expected. There’s a clear step-wise increase in median monthly income with each higher education level.
# 2. This shows a well-defined pay structure based on qualifications, likely acting as a motivating factor for career development.

# %% [markdown]
# ## Overtime, Attrition, and Employee Retention

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='OverTime', data=hr_df, palette='coolwarm')
plt.title('Overtime Distribution')
plt.show()

# %% [markdown]
# ## Overtime Distribution:
# 1. A significant number of employees work overtime, and from previous analysis, we know this is correlated with higher attrition rates.
# 2. Companies should be cautious of the potential burnout from excessive overtime work and consider monitoring work-life balance initiatives.

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition Distribution')
plt.show()

# %% [markdown]
# ### Attrition Distribution:
# The attrition rate is relatively low but still significant enough to warrant concern. Understanding the drivers behind this, such as job satisfaction, work-life balance, and overtime, will be crucial for improving retention.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='Attrition', y='Age', data=hr_df, palette='coolwarm')
plt.title('Attrition vs Age')
plt.show()

# %% [markdown]
# ### Attrition by Age:
# 1. Younger employees show higher attrition rates compared to older employees, suggesting that younger employees may either be less committed or have more job mobility.
# 2. This indicates a need for stronger engagement, mentoring, and career development programs targeted at the younger workforce.

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='Education', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Education Level')
plt.show()

# %% [markdown]
# ### Attrition by Education Level:
# Employees with lower education levels have a higher attrition rate. This may suggest that less educated employees might be in less stable or lower-paying roles, leading to higher turnover.

# %% [markdown]
# ## Role-Specific Analysis

# %%
attrition_by_role = hr_df.groupby('JobRole')['Attrition'].value_counts(normalize=True).unstack() * 100
print(attrition_by_role)

# Countplot
plt.figure(figsize=(12,6))
sns.countplot(x='JobRole', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Job Role')
plt.xticks(rotation=45)
plt.show()
# Out:
# Attrition                         No        Yes
# JobRole
# Healthcare Representative  93.129771   6.870229
# Human Resources            76.923077  23.076923
# Laboratory Technician      76.061776  23.938224
# Manager                    95.098039   4.901961
# Manufacturing Director     93.103448   6.896552
# Research Director          97.500000   2.500000
# Research Scientist         83.904110  16.095890
# Sales Executive            82.515337  17.484663
# Sales Representative       60.240964  39.759036

# %% [markdown]
# ### Attrition by Job Role:
# 1. Certain roles, like Sales Representatives, have much higher attrition rates compared to others, like Managers or Research Directors.
# 2. This could indicate that some roles are more prone to turnover due to job stress, lack of career progression, or insufficient compensation.

# %% [markdown]
# ####
# This data confirms that Sales Representatives and Laboratory Technicians have the highest attrition rates, with Sales Representatives having nearly 40% attrition. On the other hand, roles like Research Directors, Managers, and Healthcare Representatives have much lower attrition rates, often below 7%.
#
# Certain roles are more prone to turnover, especially those that are likely more stressful, have higher demands, or fewer career progression opportunities, such as Sales Representatives and Human Resources. The stability in managerial and director roles may indicate better work conditions, compensation, or job satisfaction in those positions.
#
# This insight can guide targeted retention strategies, especially for sales and laboratory staff.

# %%
import plotly.express as px
fig = px.bar(
    hr_df.groupby(["Department", "Attrition"])
    .size()
    .reset_index(name="Count"),
    x="Department",
    y="Count",
    color="Attrition",
    barmode="group",
    title='Department Count by Attrition',
    height=600,
    width=800,
    text="Count",
)

fig.update_traces(textposition='outside')

# %% [markdown]
# ## Attrition by Years at company and years since last promotion

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='YearsAtCompany', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Years At Company')
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.countplot(x='YearsSinceLastPromotion', hue='Attrition', data=hr_df, palette='coolwarm')
plt.title('Attrition by Years Since Last Promotion')
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
# List of categorical features to be encoded using Label Encoding
cat_le = ['Attrition', 'Gender', 'MaritalStatus', 'OverTime']

# Iterate over each categorical feature to apply Label Encoding
for feature in cat_le:
    
    # Initialize the LabelEncoder
    label_encoder = LabelEncoder()
    
    # Fit the encoder on the feature and transform the feature values
    hr_df[feature] = label_encoder.fit_transform(hr_df[feature])
    
    # Print information about the encoding for each feature
    print(f"\n{feature}:")
    print(f"\tClasses  : {list(label_encoder.classes_)}")
    print(f"\tEncoding : {label_encoder.transform(label_encoder.classes_)}")
# Out:
# Attrition:
# 	Classes  : [0, 1]
# 	Encoding : [0 1]
#
# Gender:
# 	Classes  : [0, 1]
# 	Encoding : [0 1]
#
# MaritalStatus:
# 	Classes  : [0, 1, 2]
# 	Encoding : [0 1 2]
#
# OverTime:
# 	Classes  : ['No', 'Yes']
# 	Encoding : [0 1]

# %%
# correlation matrix
corr_matrix = hr_df.select_dtypes(include = "number").corr()
plt.figure(figsize=(15,15))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5, cbar=True)           
plt.title("Correlation Matrix", fontsize=16)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # correlation matrix
# ----> 2 corr_matrix = hr_df.select_dtypes(include = "number").corr()
#       3 plt.figure(figsize=(15,15))
#       4 sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5, cbar=True)
#
# NameError: name 'hr_df' is not defined

# %% [markdown]
# ### Key Insights & Recommendations:
#
# 1. Focus on Employee Retention: Roles like Sales Representatives and younger employees should be key focus areas for improving retention.
# 2. Work-Life Balance: High overtime work is a likely factor driving attrition, so introducing policies to promote work-life balance could reduce turnover.
# 3. Career Development Programs: Younger employees and those with lower education levels could benefit from mentorship and career development programs to increase engagement and reduce attrition.
# 4. Diversity Initiatives: The gender imbalance suggests the need for stronger diversity and inclusion efforts, especially in recruitment and retention strategies.
